# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepu1992/VideoClassification/blob/master/micro_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #SETUP AND CONFIGURATION

# %% [markdown]
# ##TURN SECTIONS ON/OFF

# %%
MOUNT_GDRIVE    = True
CHECK_GPU_INFO  = False
DOWNLOAD_VIDEOS = False
EXTRACT_ROI     = False
EXTRACT_FEATURES= False
TRAIN_MODEL     = True

# %% [markdown]
# ##CHECK GPU USAGE

# %%
if CHECK_GPU_INFO:
    # memory footprint support libraries/code
    # !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
    # !pip install gputil
    # !pip install psutil
    # !pip install humanize
    import psutil
    import humanize
    import os
    import GPUtil as GPU
    GPUs = GPU.getGPUs()
    # XXX: only one GPU on Colab and isn’t guaranteed
    gpu = GPUs[0]
    def printm():
      process = psutil.Process(os.getpid())
      print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
      print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
    printm() 

    #!cat /proc/meminfo
    #!cat /proc/cpuinfo

# %% [markdown]
# ##DEFINE PATH VARIABLES

# %%
#define paths
PATH_PROJ = "/content/gdrive/My Drive/Google Colab Data/StallCatcher/"
PATH_ROOT = PATH_PROJ + "micro/"
VIDEO_FILES_PATH =  PATH_ROOT + "VideoData/"     #PATH TO VIDEO FILES IN GDRIVE
ROI_PATH = PATH_ROOT + "ROI/"                    #PATH TO ROI DATA
FEATURE_PATH = PATH_ROOT + "extracted_features/" #PATH TO FEATURES EXTRACTED FROM ROI
MODEL_FOLDER = PATH_ROOT + "MODEL_FOLDER/"
UTILS_PATH = "/content/gdrive/My Drive/Colab Notebooks/StallCatcher/"

#define filenames
METADATA_FILENAME = PATH_ROOT + 'train_metadata_micro.csv' #FILES LISTED WILL BE USED FOR TRAINING AND VALIDATION
LABELS_FILENAME   = PATH_PROJ + 'train_labels.csv'
MODEL_FILENAME    = MODEL_FOLDER + 'MODEL_V1_E'
BEST_MODEL_FILE   = MODEL_FOLDER + 'MODEL_BEST'

# %% [markdown]
# ##MOUNT GOOGLE DRIVE

# %%
if MOUNT_GDRIVE:
  from google.colab import drive 
  drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ##IMPORT LIBRARIES

# %%
import pandas as pd
import os
import h5py
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import warnings

warnings.filterwarnings('ignore') #u

from tensorflow.keras import models,layers,optimizers
from tensorflow.keras.layers import LSTM, Input
from random import shuffle
from sklearn.metrics import confusion_matrix,matthews_corrcoef
from tqdm.notebook import tqdm
from time import sleep
from skimage.transform import resize   # for resizing images
from os import listdir
from os.path import isfile, join
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import VGG16
from random import sample


#check if running on GPU
if tf.test.gpu_device_name() == '/device:GPU:0':
  print("Tensorflow GPU Loaded")
# Out:
# Tensorflow GPU Loaded

# %% [markdown]
# ##LOAD USER DEFINED FUNCTIONS

# %%
import sys
sys.path.append(UTILS_PATH)
from utilities import extract_roi_and_store_tensors

# %% [markdown]
# ##LOAD METADATA

# %%
train_metadata = pd.read_csv( METADATA_FILENAME)
list_of_files = list(train_metadata.filename)

# %% [markdown]
# #DOWNLOADING AND PREPROCESSING

# %% [markdown]
# ##DOWNLOAD VIDEOS

# %%
if DOWNLOAD_VIDEOS :
  #import library to interact with s3
  import boto3

  #setup s3 access
  s3r = boto3.resource('s3',
                      aws_access_key_id='AKIAR3X7R6S3PM6G56GS',
                      aws_secret_access_key= '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')
  buck = s3r.Bucket('drivendata-competition-clog-loss')

  failed = []
  for f in tqdm(list_of_files, position=0, leave=True):
      try:
        s3_path_of_video = "train/" + f
        buck.download_file(s3_path_of_video, PATH_ROOT + "VideoData/" + f) 
      except:
        failed.append(f)
        print(".", sep = "", end = "")
  if len(failed) > 0:
    print(str(len(failed)) + " files failed to load." )

# %% [markdown]
# ##EXTRACT ROI

# %%
def get_roi(frame, viz = False):
    
    #get orange coloured cells as 255 and rest as 0                                                                                                                                    
    th = cv2.inRange(frame, (9, 13, 104), (98, 143, 255))  

    #return row and column indices of orange cells                                                                                             
    points = np.where(th>0)            

    #get coordinates                                                                                                                                  
    p2 = zip(points[0], points[1])                                                                                                                                       
    p2 = [p for p in p2]               

    #get bounding box                                                                                                                                  
    rect = cv2.boundingRect(np.float32(p2))
    
    #get rectangle
    row_min,row_max,col_min,col_max = rect[0],rect[0]+rect[2],rect[1],rect[1]+rect[3]
    roi = frame[row_min:row_max,col_min:col_max,:]  
  
    if viz:
        cv2.imshow("short", roi)                                                                                                                                                  
        cv2.waitKey(1000)            
        cv2.destroyAllWindows()
    return roi

# %%
def extract_roi_and_store_tensors(filenames_list, sample_type,\
                                  roi_path, video_path, batch_size = 1000):

    assert len(filenames_list) > 0
    
    print("Extracting ROI and loading to ", sample_type, "\n")
    sleep(1)

    #path to save roi
    temp_path = roi_path + sample_type + "/" + sample_type
    
    #h5 file id
    h5_file_count = 0
    h5f   = h5py.File( temp_path + str(h5_file_count) + '.h5', 'w')
    
    ind = 0
    for videoFile in tqdm(filenames_list):               
        

        #initiate next batch
        if ind%batch_size == 0 and ind != 0:
           print(ind)
           h5f.close()
           h5_file_count +=1
           h5f = h5py.File(temp_path + str(h5_file_count) + '.h5', 'w')        
        
        #update iteration count
        ind += 1

        #id image
        count = 0    
        
        #full video path
        video_input_path = video_path + videoFile
        
        # read video
        cap = cv2.VideoCapture(video_input_path)           
        
        #number of frames
        n_frame = int(cap.get(7))

        #to get shape of tensor
        do_once = True

        while(cap.isOpened()):

            ret, frame = cap.read()
            if (ret == False):
                break
           
            if True: #sample frame here if required
                
                #subset roi from image
                roi = get_roi(frame)

                if do_once:
                  #placeholder to store roi frames
                  h,w,c = roi.shape
                  roi_tensor = np.zeros((n_frame, h,w,c))  

                if roi.shape[0] != h or roi.shape[1] != w:
                  roi = resize(roi, (h, w), preserve_range = True,
                           anti_aliasing=True) 

                #write image
                roi_tensor[count] = roi

                #update counter
                count+=1

        #normalize and save
        h5f.create_dataset(videoFile, data= roi_tensor)                      
        
        #release cap object
        cap.release()


    h5f.close()      
    sleep(1)

# %%
if EXTRACT_ROI:

    #get list of video files available
    video_filenames  = [f for f in listdir(VIDEO_FILES_PATH) if isfile(join(VIDEO_FILES_PATH, f))]

    #split data into train and test
    train,test = train_test_split(video_filenames,test_size = 0.2)
    
    #extract roi and save for train and test   
    extract_roi_and_store_tensors(filenames_list = test,  sample_type = 'test', 
                                  roi_path = ROI_PATH, video_path = VIDEO_FILES_PATH)
    extract_roi_and_store_tensors(filenames_list = train, sample_type = 'train', 
                                  roi_path = ROI_PATH, video_path = VIDEO_FILES_PATH)
# Out:
# Extracting ROI and loading to  test
# HBox(children=(FloatProgress(value=0.0, max=480.0), HTML(value='')))
# Extracting ROI and loading to  train
# HBox(children=(FloatProgress(value=0.0, max=1919.0), HTML(value='')))
# 1000

# %% [markdown]
# ##EXTRACT FEATURES

# %%
def extract_features(sample_type, roi_path, feature_path, conv_base,\
                     resize_to_shape =  (100,100,3)):
    """extracts features using the model provided"""
    
    input_folder_path = roi_path + sample_type + "/"
    roi_files = [f for f in listdir(input_folder_path) if isfile(join(input_folder_path, f))]
 
    output_folder_path = feature_path + sample_type + "/"
    
    print("Run pretrained model on {} ROI tensors".format(sample_type))
    sleep(1)
        
    print_format = "Processing batch {}/" + str(len)
    
    for batch,roi_file_name in enumerate(roi_files):

        print(print_format.format(batch+1))
        #create h5py read object for roi data
        if 'roi_read' in locals():
          roi_read.close()
        roi_read = h5py.File(input_folder_path  + roi_file_name,'r')
    
        #create h5py rewritead object for extracted features data  
        if 'feature_write' in locals():    
          feature_write.close()
        feature_write = h5py.File(output_folder_path  + roi_file_name,'w')
    
        #get video files in object
        dirFILES  = list(roi_read.keys())
        
        for file_ in tqdm(dirFILES):
            
            #read roi
            value = roi_read[file_][:]
     
            #resize_value will hold the resized frames of the roi tensor
            resize_value = np.zeros((value.shape[0], resize_to_shape[0],
                                     resize_to_shape[1],resize_to_shape[2]))
            
            for frame in range(value.shape[0]):
                #resize    
                resize_value[frame] = resize(value[frame], resize_to_shape, 
                                    preserve_range = True,
                                    anti_aliasing=True)  
                
            #apply pre trained model on roi frame of sample
            feature = conv_base.predict(np.array(resize_value))
    
            #reshape to (n_frames, 3*3*512)
            feature = feature.reshape(feature.shape[0], np.product(feature.shape[1:]))
    
            feature_write.create_dataset(file_, data= feature)   
    
        #close h5py objects
        feature_write.close()
        roi_read.close()

# %%
if EXTRACT_FEATURES:
    conv_base = VGG16(weights='imagenet', include_top=False,input_shape=(100, 100, 3))
    #conv_base.summary()
    sleep(1)
    
    #extract feature for train,test   
    extract_features(sample_type = 'test',  roi_path = ROI_PATH, 
                    feature_path = FEATURE_PATH, 
                    conv_base = conv_base )
    sleep(1)
    extract_features(sample_type = 'train',  roi_path = ROI_PATH, 
                    feature_path = FEATURE_PATH, 
                    conv_base = conv_base )
# Out:
# Run pretrained model on test ROI tensors
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Run pretrained model on train ROI tensors
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))

# %% [markdown]
# #MODEL TRAINING

# %% [markdown]
# ##SET MODEL ARCHITECTURE

# %%
#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' #turn off warnings  
tf.get_logger().setLevel('INFO')
#define model architecture
model = models.Sequential()
model.add(LSTM(100, input_shape = (None,3*3* 512)))
model.add(layers.Dense(256, input_dim=(3*3* 512), activation='relu'))#, input_dim=(3*3* 512)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer=optimizers.RMSprop(lr=2e-5),
                                              loss='binary_crossentropy',
                                              metrics=['acc'])

# %% [markdown]
# ##LOAD TRAIN AND TEST DATA

# %%
if TRAIN_MODEL:
    from random import choice
    
    sub_path = FEATURE_PATH + 'train' + "/"
    train_options = [f for f in listdir(sub_path) if isfile(join(sub_path, f))]
     
    def load_data(choice_train_set):

      #fetch train,test  features
      sample_type  = 'test'
      sub_path     = FEATURE_PATH + sample_type + "/"
      options      = [f for f in listdir(sub_path) if isfile(join(sub_path, f))]
      feature_read = h5py.File(sub_path + choice(options),'r')
      test = list(feature_read.keys())
      test_features = [i[:] for i in feature_read.values()]
      feature_read.close()
      print("Test features loaded")

      sample_type = 'train'
      sub_path     = FEATURE_PATH + sample_type + "/"
      feature_read = h5py.File(sub_path + choice_train_set,'r')
      train = list(feature_read.keys())
      train_features = [i[:] for i in feature_read.values()]
      feature_read.close()
      print("Train features loaded")

      #convert to arrays
      train_features = np.array(train_features)
      test_features  = np.array(test_features)

      #load label dataframe
      df_label = pd.read_csv(LABELS_FILENAME)
      df_label.set_index('filename', inplace = True)

      #fetch train,test labels
      test_labels  = np.array( list(df_label.loc[[i  for i in test]].stalled) )
      print("Test Labels loaded")
      train_labels = np.array( list(df_label.loc[[i  for i in train]].stalled))
      print("Train Labels loaded")

      return train_features, train_labels, test_features, test_labels

# %% [markdown]
# ##TRAIN MODEL

# %%
if TRAIN_MODEL:
  
  batch_size = 10


  test_accuracy  = [0]
  test_mcc       = [0]
  train_accuracy = [0]
  train_mcc      = [0]
  checkpoint     = 50

  class_weights = {0: 3,
                1: 7}
  
  for set_num, choice_train_set in enumerate(train_options):
      train_features, train_labels, test_features, test_labels = load_data(choice_train_set)
      n_records = train_labels.shape[0]
      for epoch in range(1,3000):

              print("\n\nIteration: ", epoch)

              #generaate indexes for sampling
              samples_drawn = np.array(sample(range(n_records),batch_size))
              
              #sample from features
              x_samples     = np.array(train_features)[samples_drawn]

              #reshape features to have same first dimension
              min_rec       = min([i.shape[0] for i in x_samples])
              x_samples     = np.array([i[-min_rec:] for i in x_samples])

              #get labels
              y_samples      = np.array([[i] for i in train_labels[samples_drawn]])

              #fit NN
              history = model.fit(x_samples,y_samples,batch_size = 5, 
                                  epochs = 2, class_weight=class_weights)#, verbose = False)

              if  epoch%checkpoint == 0:
                  print("Evaluating on training data")
                  pred = [model.predict(np.array([i]))[0][0] for i in train_features]
                  
                  pred_       = [1 if i > .5 else 0 for i in pred]
                  mcc         = np.round(matthews_corrcoef(train_labels, pred_),2)
                  train_acc   = confusion_matrix(train_labels.flatten(),pred_)
                  train_acc   = np.round(sum(train_acc.diagonal()) / train_acc.sum(),2)

                  train_accuracy.append(train_acc)
                  train_mcc.append(mcc)
                  print("Train Accuracy" , train_acc)            
                  #print("Train Accuracy History: ",train_accuracy[-5:])
                  print("\nTrain MCC: ",mcc)
                  #print("Train MCC History:      ",train_mcc[-5:])

                  n_cp = len(train_accuracy)
                  df_train_cp = pd.DataFrame({"Epoch"          : range(n_cp),
                                              "Train_Accuracy" : train_accuracy, 
                                              "Train MCC"      : train_mcc})
                  df_train_cp.to_csv(MODEL_FOLDER + "MODEL_RESULTS/TRAIN_PERF.csv")

              if  epoch%5 == 0 or epoch%checkpoint == 0:
                  print("Evaluating on test data")
                  pred = [model.predict(np.array([i]))[0][0] for i in test_features]            
                  
                  pred_  = [1 if i > .5 else 0 for i in pred]
                  mcc    = np.round(matthews_corrcoef(test_labels, pred_),2)
                  acc    = confusion_matrix(test_labels.flatten(),pred_)
                  acc    = np.round(sum(acc.diagonal()) / acc.sum(),2)

                  if mcc > max(test_mcc):
                    model.save(BEST_MODEL_FILE)
                  test_accuracy.append(acc)
                  test_mcc.append(mcc)
                  print("\n\nTest Accuracy" , acc)            
                  #print("Test Accuracy History: ",test_accuracy[-5:])
                  print("\nTest MCC: ",mcc)
                  #print("Test MCC History: "     ,test_mcc[-5:])
                  print("------------\n\n")

                  n_cp = len(test_accuracy)
                  df_test_cp = pd.DataFrame({"Epoch"          : range(n_cp),
                                              "Test_Accuracy" : test_accuracy, 
                                              "Test_MCC"      : test_mcc})
                  df_test_cp.to_csv(MODEL_FOLDER + "MODEL_RESULTS/TEST_PERF.csv")

              if epoch%checkpoint == 0:
                  model.save(MODEL_FILENAME + "{}_{}".format(set_num, epoch))
# Out:
# Test features loaded
# Train features loaded
# Test Labels loaded
# Train Labels loaded
#
#
# Iteration:  1
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.9559 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.1450 - acc: 0.6000
#
#
# Iteration:  2
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.3166 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 7ms/step - loss: 2.9342 - acc: 0.8000
#
#
# Iteration:  3
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.0633 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 6ms/step - loss: 3.4699 - acc: 0.5000
#
#
# Iteration:  4
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 5.2438 - acc: 0.5000
# Epoch 2/2
# 2/2 [==============================] - 0s 6ms/step - loss: 3.7140 - acc: 0.6000
#
#
# Iteration:  5
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 3.3399 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 6ms/step - loss: 3.1615 - acc: 0.7000
# Evaluating on test data
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Google Colab Data/StallCatcher/micro/MODEL_FOLDER/MODEL_BEST/assets
#
#
# Test Accuracy 0.69
#
# Test MCC:  0.09
# ------------
#
#
#
#
# Iteration:  6
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.6492 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.0245 - acc: 0.7000
#
#
# Iteration:  7
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.2667 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.3825 - acc: 0.8000
#
#
# Iteration:  8
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1559 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4507 - acc: 0.8000
#
#
# Iteration:  9
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9884 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 3ms/step - loss: 2.3310 - acc: 0.6000
#
#
# Iteration:  10
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5603 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 6ms/step - loss: 2.9968 - acc: 0.6000
# Evaluating on test data
#
#
# Test Accuracy 0.69
#
# Test MCC:  0.06
# ------------
#
#
#
#
# Iteration:  11
# Epoch 1/2
# 2/2 [==============================] - 0s 7ms/step - loss: 3.9820 - acc: 0.5000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.1650 - acc: 0.5000
#
#
# Iteration:  12
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 3.3149 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.0360 - acc: 0.8000
#
#
# Iteration:  13
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.3627 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7605 - acc: 0.6000
#
#
# Iteration:  14
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 1.5722 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.7248 - acc: 0.8000
#
#
# Iteration:  15
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9612 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.4356 - acc: 0.7000
# Evaluating on test data
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Google Colab Data/StallCatcher/micro/MODEL_FOLDER/MODEL_BEST/assets
#
#
# Test Accuracy 0.7
#
# Test MCC:  0.11
# ------------
#
#
#
#
# Iteration:  16
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7299 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 6ms/step - loss: 2.8959 - acc: 0.6000
#
#
# Iteration:  17
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.1910 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.3148 - acc: 0.7000
#
#
# Iteration:  18
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0788 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9014 - acc: 0.8000
#
#
# Iteration:  19
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.4709 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.9477 - acc: 0.7000
#
#
# Iteration:  20
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.2026 - acc: 0.5000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.1187 - acc: 0.6000
# Evaluating on test data
#
#
# Test Accuracy 0.69
#
# Test MCC:  0.1
# ------------
#
#
#
#
# Iteration:  21
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 3.7943 - acc: 0.3000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0441 - acc: 0.9000
#
#
# Iteration:  22
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.0785 - acc: 0.5000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.9752 - acc: 0.4000
#
#
# Iteration:  23
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0667 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1463 - acc: 0.8000
#
#
# Iteration:  24
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.2035 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 3ms/step - loss: 2.7915 - acc: 0.7000
#
#
# Iteration:  25
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7694 - acc: 0.4000
# Epoch 2/2
# 2/2 [==============================] - 0s 3ms/step - loss: 1.4470 - acc: 1.0000
# Evaluating on test data
#
#
# Test Accuracy 0.69
#
# Test MCC:  0.08
# ------------
#
#
#
#
# Iteration:  26
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.2220 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.2417 - acc: 0.7000
#
#
# Iteration:  27
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.6444 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.4501 - acc: 0.8000
#
#
# Iteration:  28
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0051 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0199 - acc: 0.9000
#
#
# Iteration:  29
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1309 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.5537 - acc: 0.7000
#
#
# Iteration:  30
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.1554 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.9351 - acc: 0.6000
# Evaluating on test data
#
#
# Test Accuracy 0.7
#
# Test MCC:  0.1
# ------------
#
#
#
#
# Iteration:  31
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2431 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.6559 - acc: 0.9000
#
#
# Iteration:  32
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.6438 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.8337 - acc: 0.7000
#
#
# Iteration:  33
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.6390 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.7167 - acc: 0.7000
#
#
# Iteration:  34
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9200 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.4960 - acc: 0.7000
#
#
# Iteration:  35
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1008 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.2673 - acc: 0.7000
# Evaluating on test data
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Google Colab Data/StallCatcher/micro/MODEL_FOLDER/MODEL_BEST/assets
#
#
# Test Accuracy 0.71
#
# Test MCC:  0.15
# ------------
#
#
#
#
# Iteration:  36
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.3111 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0784 - acc: 0.8000
#
#
# Iteration:  37
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.3198 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1994 - acc: 0.9000
#
#
# Iteration:  38
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.4625 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.9187 - acc: 0.8000
#
#
# Iteration:  39
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2911 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.8950 - acc: 0.7000
#
#
# Iteration:  40
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 2.8229 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2126 - acc: 0.8000
# Evaluating on test data
#
#
# Test Accuracy 0.71
#
# Test MCC:  0.13
# ------------
#
#
#
#
# Iteration:  41
# Epoch 1/2
# 2/2 [==============================] - 0s 8ms/step - loss: 1.8540 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9006 - acc: 0.8000
#
#
# Iteration:  42
# Epoch 1/2
# 2/2 [==============================] - 0s 7ms/step - loss: 3.2942 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.7802 - acc: 0.7000
#
#
# Iteration:  43
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.6413 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0898 - acc: 0.9000
#
#
# Iteration:  44
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.3403 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.6125 - acc: 0.6000
#
#
# Iteration:  45
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.5306 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5752 - acc: 0.7000
# Evaluating on test data
#
#
# Test Accuracy 0.7
#
# Test MCC:  0.12
# ------------
#
#
#
#
# Iteration:  46
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.9143 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.6588 - acc: 0.7000
#
#
# Iteration:  47
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0069 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.8003 - acc: 0.8000
#
#
# Iteration:  48
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 4.0071 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.5485 - acc: 0.4000
#
#
# Iteration:  49
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.8081 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.3162 - acc: 0.8000
#
#
# Iteration:  50
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.4758 - acc: 0.5000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.8948 - acc: 0.7000
# Evaluating on training data
# Train Accuracy 0.73
#
# Train MCC:  0.26
# Evaluating on test data
#
#
# Test Accuracy 0.71
#
# Test MCC:  0.14
# ------------
#
#
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Google Colab Data/StallCatcher/micro/MODEL_FOLDER/MODEL_V1_E0_50/assets
#
#
# Iteration:  51
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.4088 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.6496 - acc: 0.7000
#
#
# Iteration:  52
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.9982 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 3ms/step - loss: 3.0055 - acc: 0.6000
#
#
# Iteration:  53
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.8601 - acc: 0.5000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.8905 - acc: 0.5000
#
#
# Iteration:  54
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.4327 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1350 - acc: 0.8000
#
#
# Iteration:  55
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.5737 - acc: 0.5000
# Epoch 2/2
# 2/2 [==============================] - 0s 3ms/step - loss: 2.6534 - acc: 0.7000
# Evaluating on test data
#
#
# Test Accuracy 0.7
#
# Test MCC:  0.12
# ------------
#
#
#
#
# Iteration:  56
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1477 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5982 - acc: 0.7000
#
#
# Iteration:  57
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4667 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.0691 - acc: 0.7000
#
#
# Iteration:  58
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.7499 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9303 - acc: 0.8000
#
#
# Iteration:  59
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.8016 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.7026 - acc: 0.9000
#
#
# Iteration:  60
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9973 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.6907 - acc: 0.8000
# Evaluating on test data
#
#
# Test Accuracy 0.71
#
# Test MCC:  0.13
# ------------
#
#
#
#
# Iteration:  61
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.3926 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5618 - acc: 0.7000
#
#
# Iteration:  62
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.4569 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 3ms/step - loss: 1.8153 - acc: 0.9000
#
#
# Iteration:  63
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.2457 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.4227 - acc: 0.6000
#
#
# Iteration:  64
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.2282 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.8685 - acc: 0.7000
#
#
# Iteration:  65
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 2.9419 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.2642 - acc: 0.6000
# Evaluating on test data
#
#
# Test Accuracy 0.7
#
# Test MCC:  0.13
# ------------
#
#
#
#
# Iteration:  66
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 4.1323 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 7ms/step - loss: 2.7571 - acc: 0.7000
#
#
# Iteration:  67
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.5910 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.2516 - acc: 0.5000
#
#
# Iteration:  68
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9252 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 3ms/step - loss: 1.6679 - acc: 1.0000
#
#
# Iteration:  69
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.6225 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1005 - acc: 0.8000
#
#
# Iteration:  70
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.1804 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.0315 - acc: 0.5000
# Evaluating on test data
#
#
# Test Accuracy 0.7
#
# Test MCC:  0.15
# ------------
#
#
#
#
# Iteration:  71
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 5.3188 - acc: 0.3000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.9982 - acc: 0.3000
#
#
# Iteration:  72
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.8061 - acc: 0.5000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.0947 - acc: 0.5000
#
#
# Iteration:  73
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.2820 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 7ms/step - loss: 3.2419 - acc: 0.7000
#
#
# Iteration:  74
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.7997 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.9140 - acc: 0.6000
#
#
# Iteration:  75
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.6742 - acc: 0.5000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.1988 - acc: 0.5000
# Evaluating on test data
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Google Colab Data/StallCatcher/micro/MODEL_FOLDER/MODEL_BEST/assets
#
#
# Test Accuracy 0.69
#
# Test MCC:  0.16
# ------------
#
#
#
#
# Iteration:  76
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.2360 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1668 - acc: 0.7000
#
#
# Iteration:  77
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.4191 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1662 - acc: 0.8000
#
#
# Iteration:  78
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.6404 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.9248 - acc: 0.5000
#
#
# Iteration:  79
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.6923 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.2814 - acc: 0.5000
#
#
# Iteration:  80
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 4.2275 - acc: 0.5000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.2458 - acc: 0.4000
# Evaluating on test data
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Google Colab Data/StallCatcher/micro/MODEL_FOLDER/MODEL_BEST/assets
#
#
# Test Accuracy 0.69
#
# Test MCC:  0.17
# ------------
#
#
#
#
# Iteration:  81
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9749 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9363 - acc: 0.9000
#
#
# Iteration:  82
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.0591 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4982 - acc: 0.5000
#
#
# Iteration:  83
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.5715 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.0518 - acc: 0.7000
#
#
# Iteration:  84
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0844 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.7757 - acc: 0.8000
#
#
# Iteration:  85
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.8782 - acc: 0.4000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.5853 - acc: 0.7000
# Evaluating on test data
#
#
# Test Accuracy 0.69
#
# Test MCC:  0.14
# ------------
#
#
#
#
# Iteration:  86
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.9294 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.4008 - acc: 0.7000
#
#
# Iteration:  87
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.4458 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.0050 - acc: 0.6000
#
#
# Iteration:  88
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4643 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 3ms/step - loss: 2.2314 - acc: 0.8000
#
#
# Iteration:  89
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.8043 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.9096 - acc: 0.7000
#
#
# Iteration:  90
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.7373 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.7975 - acc: 0.6000
# Evaluating on test data
#
#
# Test Accuracy 0.68
#
# Test MCC:  0.13
# ------------
#
#
#
#
# Iteration:  91
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2371 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0233 - acc: 0.7000
#
#
# Iteration:  92
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.8335 - acc: 0.3000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.8633 - acc: 0.6000
#
#
# Iteration:  93
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.6726 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4008 - acc: 0.8000
#
#
# Iteration:  94
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9559 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.7113 - acc: 0.9000
#
#
# Iteration:  95
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 2.5573 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9205 - acc: 0.8000
# Evaluating on test data
#
#
# Test Accuracy 0.69
#
# Test MCC:  0.14
# ------------
#
#
#
#
# Iteration:  96
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 3.0237 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.4252 - acc: 0.5000
#
#
# Iteration:  97
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2834 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.2785 - acc: 0.8000
#
#
# Iteration:  98
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 4.0632 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.1422 - acc: 0.6000
#
#
# Iteration:  99
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.7944 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.6271 - acc: 0.8000
#
#
# Iteration:  100
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.3605 - acc: 0.4000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.7619 - acc: 0.3000
# Evaluating on training data
# Train Accuracy 0.74
#
# Train MCC:  0.31
# Evaluating on test data
#
#
# Test Accuracy 0.69
#
# Test MCC:  0.17
# ------------
#
#
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Google Colab Data/StallCatcher/micro/MODEL_FOLDER/MODEL_V1_E0_100/assets
#
#
# Iteration:  101
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.9195 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.2603 - acc: 0.6000
#
#
# Iteration:  102
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1310 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1340 - acc: 0.9000
#
#
# Iteration:  103
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.9150 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.3765 - acc: 0.3000
#
#
# Iteration:  104
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.3395 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.6691 - acc: 0.7000
#
#
# Iteration:  105
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.9164 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 7ms/step - loss: 2.2995 - acc: 0.8000
# Evaluating on test data
#
#
# Test Accuracy 0.69
#
# Test MCC:  0.15
# ------------
#
#
#
#
# Iteration:  106
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7604 - acc: 0.5000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.6079 - acc: 0.9000
#
#
# Iteration:  107
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.4862 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.5022 - acc: 0.9000
#
#
# Iteration:  108
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.5594 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4657 - acc: 0.8000
#
#
# Iteration:  109
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.7304 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.7316 - acc: 0.6000
#
#
# Iteration:  110
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2806 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1268 - acc: 0.9000
# Evaluating on test data
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Google Colab Data/StallCatcher/micro/MODEL_FOLDER/MODEL_BEST/assets
#
#
# Test Accuracy 0.7
#
# Test MCC:  0.18
# ------------
#
#
#
#
# Iteration:  111
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.3736 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4244 - acc: 0.7000
#
#
# Iteration:  112
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.9119 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.3087 - acc: 0.8000
#
#
# Iteration:  113
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.3404 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.6449 - acc: 0.7000
#
#
# Iteration:  114
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.5384 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5135 - acc: 0.8000
#
#
# Iteration:  115
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.5976 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.8113 - acc: 0.7000
# Evaluating on test data
#
#
# Test Accuracy 0.69
#
# Test MCC:  0.16
# ------------
#
#
#
#
# Iteration:  116
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 2.3253 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.1940 - acc: 0.6000
#
#
# Iteration:  117
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.5766 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5316 - acc: 0.9000
#
#
# Iteration:  118
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.7792 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0237 - acc: 0.8000
#
#
# Iteration:  119
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.5199 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0066 - acc: 0.9000
#
#
# Iteration:  120
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.5748 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.7799 - acc: 0.9000
# Evaluating on test data
#
#
# Test Accuracy 0.69
#
# Test MCC:  0.15
# ------------
#
#
#
#
# Iteration:  121
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.4478 - acc: 1.0000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.3083 - acc: 1.0000
#
#
# Iteration:  122
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.1254 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.4209 - acc: 0.5000
#
#
# Iteration:  123
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.9404 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1724 - acc: 0.7000
#
#
# Iteration:  124
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.6443 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.4924 - acc: 0.7000
#
#
# Iteration:  125
# Epoch 1/2
# 2/2 [==============================] - 0s 7ms/step - loss: 1.4840 - acc: 1.0000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9465 - acc: 0.6000
# Evaluating on test data
#
#
# Test Accuracy 0.69
#
# Test MCC:  0.13
# ------------
#
#
#
#
# Iteration:  126
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0029 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0111 - acc: 0.9000
#
#
# Iteration:  127
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.7856 - acc: 0.5000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.8019 - acc: 0.7000
#
#
# Iteration:  128
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2437 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2371 - acc: 0.8000
#
#
# Iteration:  129
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 1.9667 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2348 - acc: 0.7000
#
#
# Iteration:  130
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7791 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.8499 - acc: 0.7000
# Evaluating on test data
#
#
# Test Accuracy 0.7
#
# Test MCC:  0.16
# ------------
#
#
#
#
# Iteration:  131
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1852 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4375 - acc: 0.7000
#
#
# Iteration:  132
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.0488 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.0303 - acc: 0.7000
#
#
# Iteration:  133
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.5300 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.3117 - acc: 0.8000
#
#
# Iteration:  134
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.8388 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5669 - acc: 0.5000
#
#
# Iteration:  135
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.7811 - acc: 0.5000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 4.2318 - acc: 0.3000
# Evaluating on test data
#
#
# Test Accuracy 0.7
#
# Test MCC:  0.15
# ------------
#
#
#
#
# Iteration:  136
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 1.1611 - acc: 1.0000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.0460 - acc: 1.0000
#
#
# Iteration:  137
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2209 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.8691 - acc: 0.7000
#
#
# Iteration:  138
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7962 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4151 - acc: 0.9000
#
#
# Iteration:  139
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1178 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 7ms/step - loss: 2.7901 - acc: 0.8000
#
#
# Iteration:  140
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.5012 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1487 - acc: 0.9000
# Evaluating on test data
#
#
# Test Accuracy 0.71
#
# Test MCC:  0.16
# ------------
#
#
#
#
# Iteration:  141
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 3.1175 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 6ms/step - loss: 2.9372 - acc: 0.5000
#
#
# Iteration:  142
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.8884 - acc: 0.4000
# Epoch 2/2
# 2/2 [==============================] - 0s 6ms/step - loss: 3.9570 - acc: 0.5000
#
#
# Iteration:  143
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.7234 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 6ms/step - loss: 3.6469 - acc: 0.6000
#
#
# Iteration:  144
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.7599 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 6ms/step - loss: 2.0965 - acc: 0.8000
#
#
# Iteration:  145
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.6942 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 6ms/step - loss: 2.5015 - acc: 0.8000
# Evaluating on test data
#
#
# Test Accuracy 0.71
#
# Test MCC:  0.16
# ------------
#
#
#
#
# Iteration:  146
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9515 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1830 - acc: 0.7000
#
#
# Iteration:  147
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.2845 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.3241 - acc: 0.7000
#
#
# Iteration:  148
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.3870 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.5431 - acc: 0.9000
#
#
# Iteration:  149
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4338 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1326 - acc: 1.0000
#
#
# Iteration:  150
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.1613 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.2338 - acc: 0.6000
# Evaluating on training data
# Train Accuracy 0.75
#
# Train MCC:  0.32
# Evaluating on test data
#
#
# Test Accuracy 0.7
#
# Test MCC:  0.16
# ------------
#
#
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Google Colab Data/StallCatcher/micro/MODEL_FOLDER/MODEL_V1_E0_150/assets
#
#
# Iteration:  151
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 3.0911 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 4.3988 - acc: 0.6000
#
#
# Iteration:  152
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1079 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0543 - acc: 0.9000
#
#
# Iteration:  153
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.9898 - acc: 0.5000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 5.3024 - acc: 0.4000
#
#
# Iteration:  154
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1228 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.4836 - acc: 0.9000
#
#
# Iteration:  155
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.6304 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.4810 - acc: 0.7000
# Evaluating on test data
#
#
# Test Accuracy 0.69
#
# Test MCC:  0.15
# ------------
#
#
#
#
# Iteration:  156
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7542 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0700 - acc: 0.9000
#
#
# Iteration:  157
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 4.1187 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.2040 - acc: 0.6000
#
#
# Iteration:  158
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.6277 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0008 - acc: 0.7000
#
#
# Iteration:  159
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.8123 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.8117 - acc: 0.7000
#
#
# Iteration:  160
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.5300 - acc: 0.5000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.9978 - acc: 0.8000
# Evaluating on test data
#
#
# Test Accuracy 0.69
#
# Test MCC:  0.14
# ------------
#
#
#
#
# Iteration:  161
# Epoch 1/2
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0027 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.7112 - acc: 0.8000
#
#
# Iteration:  162
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.8608 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5603 - acc: 0.6000
#
#
# Iteration:  163
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.7108 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.7417 - acc: 1.0000
#
#
# Iteration:  164
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.2450 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.5672 - acc: 0.5000
#
#
# Iteration:  165
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.0609 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.0191 - acc: 0.7000
# Evaluating on test data
#
#
# Test Accuracy 0.68
#
# Test MCC:  0.12
# ------------
#
#
#
#
# Iteration:  166
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.7886 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.6669 - acc: 0.7000
#
#
# Iteration:  167
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.0799 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4252 - acc: 0.9000
#
#
# Iteration:  168
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1580 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0912 - acc: 0.8000
#
#
# Iteration:  169
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.6347 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.2448 - acc: 0.6000
#
#
# Iteration:  170
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.4394 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.1047 - acc: 0.7000
# Evaluating on test data
#
#
# Test Accuracy 0.68
#
# Test MCC:  0.12
# ------------
#
#
#
#
# Iteration:  171
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 2.3618 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4845 - acc: 0.7000
#
#
# Iteration:  172
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.6391 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.3601 - acc: 0.6000
#
#
# Iteration:  173
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.3696 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.9355 - acc: 0.7000
#
#
# Iteration:  174
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.6913 - acc: 0.5000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.3388 - acc: 0.3000
#
#
# Iteration:  175
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.1947 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5954 - acc: 0.7000
# Evaluating on test data
#
#
# Test Accuracy 0.68
#
# Test MCC:  0.12
# ------------
#
#
#
#
# Iteration:  176
# Epoch 1/2
# 2/2 [==============================] - 0s 7ms/step - loss: 2.9800 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.0340 - acc: 0.7000
#
#
# Iteration:  177
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.3650 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.2715 - acc: 0.8000
#
#
# Iteration:  178
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.9844 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.0249 - acc: 0.9000
#
#
# Iteration:  179
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.2216 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4446 - acc: 0.7000
#
#
# Iteration:  180
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.7322 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5364 - acc: 0.8000
# Evaluating on test data
#
#
# Test Accuracy 0.67
#
# Test MCC:  0.12
# ------------
#
#
#
#
# Iteration:  181
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7833 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0346 - acc: 0.8000
#
#
# Iteration:  182
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1068 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.2739 - acc: 0.7000
#
#
# Iteration:  183
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.6549 - acc: 0.5000
# Epoch 2/2
# 2/2 [==============================] - 0s 3ms/step - loss: 3.6659 - acc: 0.5000
#
#
# Iteration:  184
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.6852 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.8116 - acc: 0.4000
#
#
# Iteration:  185
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9766 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0311 - acc: 0.9000
# Evaluating on test data
#
#
# Test Accuracy 0.67
#
# Test MCC:  0.1
# ------------
#
#
#
#
# Iteration:  186
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 2.5538 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.8241 - acc: 1.0000
#
#
# Iteration:  187
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.5589 - acc: 0.4000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4372 - acc: 0.7000
#
#
# Iteration:  188
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9842 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1561 - acc: 0.8000
#
#
# Iteration:  189
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.3978 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.0305 - acc: 0.7000
#
#
# Iteration:  190
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.6321 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1585 - acc: 0.7000
# Evaluating on test data
#
#
# Test Accuracy 0.68
#
# Test MCC:  0.11
# ------------
#
#
#
#
# Iteration:  191
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 2.0880 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.7546 - acc: 0.7000
#
#
# Iteration:  192
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9534 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.7472 - acc: 0.9000
#
#
# Iteration:  193
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.3063 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 3ms/step - loss: 2.2249 - acc: 0.7000
#
#
# Iteration:  194
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3268 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.2234 - acc: 0.8000
#
#
# Iteration:  195
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.1897 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.8004 - acc: 0.6000
# Evaluating on test data
#
#
# Test Accuracy 0.69
#
# Test MCC:  0.13
# ------------
#
#
#
#
# Iteration:  196
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2916 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.6604 - acc: 0.8000
#
#
# Iteration:  197
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.1457 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.9125 - acc: 0.7000
#
#
# Iteration:  198
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7273 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.5980 - acc: 0.9000
#
#
# Iteration:  199
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.8567 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.9992 - acc: 0.7000
#
#
# Iteration:  200
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.3800 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.1823 - acc: 0.6000
# Evaluating on training data
# Train Accuracy 0.74
#
# Train MCC:  0.32
# Evaluating on test data
#
#
# Test Accuracy 0.69
#
# Test MCC:  0.14
# ------------
#
#
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Google Colab Data/StallCatcher/micro/MODEL_FOLDER/MODEL_V1_E0_200/assets
#
#
# Iteration:  201
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.6708 - acc: 0.4000
# Epoch 2/2
# 2/2 [==============================] - 0s 3ms/step - loss: 4.3177 - acc: 0.7000
#
#
# Iteration:  202
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.1263 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.7074 - acc: 0.7000
#
#
# Iteration:  203
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.1435 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.7482 - acc: 0.6000
#
#
# Iteration:  204
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.0294 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.6990 - acc: 0.8000
#
#
# Iteration:  205
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5097 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0681 - acc: 1.0000
# Evaluating on test data
#
#
# Test Accuracy 0.68
#
# Test MCC:  0.13
# ------------
#
#
#
#
# Iteration:  206
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0850 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.7663 - acc: 0.7000
#
#
# Iteration:  207
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0276 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5241 - acc: 0.6000
#
#
# Iteration:  208
# Epoch 1/2
# 2/2 [==============================] - 0s 3ms/step - loss: 2.1319 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4606 - acc: 0.7000
#
#
# Iteration:  209
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.7427 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 3ms/step - loss: 2.7908 - acc: 0.7000
#
#
# Iteration:  210
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2921 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 6ms/step - loss: 1.8497 - acc: 0.9000
# Evaluating on test data
#
#
# Test Accuracy 0.68
#
# Test MCC:  0.1
# ------------
#
#
#
#
# Iteration:  211
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 1.8425 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.6297 - acc: 1.0000
#
#
# Iteration:  212
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 5.0013 - acc: 0.5000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.1168 - acc: 0.5000
#
#
# Iteration:  213
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.1809 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 3ms/step - loss: 2.9350 - acc: 0.7000
#
#
# Iteration:  214
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.7314 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.1566 - acc: 0.8000
#
#
# Iteration:  215
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2493 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5141 - acc: 0.7000
# Evaluating on test data
#
#
# Test Accuracy 0.67
#
# Test MCC:  0.09
# ------------
#
#
#
#
# Iteration:  216
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2303 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5716 - acc: 0.8000
#
#
# Iteration:  217
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.3043 - acc: 1.0000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.2015 - acc: 0.9000
#
#
# Iteration:  218
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.9202 - acc: 0.5000
# Epoch 2/2
# 2/2 [==============================] - 0s 3ms/step - loss: 2.2316 - acc: 0.8000
#
#
# ...
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0628 - acc: 0.7000
#
#
# Iteration:  349
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.6880 - acc: 0.3000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.5805 - acc: 0.6000
#
#
# Iteration:  350
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.0787 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0273 - acc: 0.8000
# Evaluating on training data
# Train Accuracy 0.76
#
# Train MCC:  0.37
# Evaluating on test data
#
#
# Test Accuracy 0.69
#
# Test MCC:  0.13
# ------------
#
#
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Google Colab Data/StallCatcher/micro/MODEL_FOLDER/MODEL_V1_E0_350/assets
#
#
# Iteration:  351
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.2827 - acc: 0.4000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.9007 - acc: 0.5000
#
#
# Iteration:  352
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.5813 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9385 - acc: 0.9000
#
#
# Iteration:  353
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2412 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.4554 - acc: 0.9000
#
#
# Iteration:  354
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0554 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 3ms/step - loss: 3.0388 - acc: 0.6000
#
#
# Iteration:  355
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.8191 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.6347 - acc: 0.6000
# Evaluating on test data
#
#
# Test Accuracy 0.68
#
# Test MCC:  0.11
# ------------
#
#
#
#
# Iteration:  356
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.7859 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.8145 - acc: 0.8000
#
#
# Iteration:  357
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.6354 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.6920 - acc: 0.5000
#
#
# Iteration:  358
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.4676 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.4171 - acc: 1.0000
#
#
# Iteration:  359
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 4.3296 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 4.7264 - acc: 0.4000
#
#
# Iteration:  360
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.1886 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.9016 - acc: 0.7000
# Evaluating on test data
#
#
# Test Accuracy 0.68
#
# Test MCC:  0.14
# ------------
#
#
#
#
# Iteration:  361
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.4764 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0589 - acc: 0.8000
#
#
# Iteration:  362
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.2355 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 3ms/step - loss: 4.8815 - acc: 0.4000
#
#
# Iteration:  363
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.2379 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1940 - acc: 0.9000
#
#
# Iteration:  364
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.3765 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0479 - acc: 0.8000
#
#
# Iteration:  365
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.4987 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.9613 - acc: 0.7000
# Evaluating on test data
#
#
# Test Accuracy 0.69
#
# Test MCC:  0.17
# ------------
#
#
#
#
# Iteration:  366
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 3.1629 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.7617 - acc: 0.6000
#
#
# Iteration:  367
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9511 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.6818 - acc: 0.9000
#
#
# Iteration:  368
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.5992 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.2146 - acc: 0.8000
#
#
# Iteration:  369
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0314 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.9057 - acc: 0.9000
#
#
# Iteration:  370
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.1788 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0965 - acc: 0.9000
# Evaluating on test data
#
#
# Test Accuracy 0.68
#
# Test MCC:  0.13
# ------------
#
#
#
#
# Iteration:  371
# Epoch 1/2
# 2/2 [==============================] - 0s 7ms/step - loss: 2.4647 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.5861 - acc: 0.8000
#
#
# Iteration:  372
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.4600 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.2170 - acc: 0.8000
#
#
# Iteration:  373
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.1601 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.1639 - acc: 0.7000
#
#
# Iteration:  374
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.1167 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.0015 - acc: 0.7000
#
#
# Iteration:  375
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.4694 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.0405 - acc: 0.5000
# Evaluating on test data
#
#
# Test Accuracy 0.67
#
# Test MCC:  0.1
# ------------
#
#
#
#
# Iteration:  376
# Epoch 1/2
# 2/2 [==============================] - 0s 7ms/step - loss: 1.5864 - acc: 1.0000
# Epoch 2/2
# 2/2 [==============================] - 0s 7ms/step - loss: 1.2635 - acc: 0.9000
#
#
# Iteration:  377
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.9316 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.4286 - acc: 0.5000
#
#
# Iteration:  378
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.5085 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.6830 - acc: 0.9000
#
#
# Iteration:  379
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.8687 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.4591 - acc: 1.0000
#
#
# Iteration:  380
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1010 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0934 - acc: 0.7000
# Evaluating on test data
#
#
# Test Accuracy 0.68
#
# Test MCC:  0.11
# ------------
#
#
#
#
# Iteration:  381
# Epoch 1/2
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0728 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.6790 - acc: 1.0000
#
#
# Iteration:  382
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.3064 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.8205 - acc: 0.8000
#
#
# Iteration:  383
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.3783 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.9918 - acc: 0.6000
#
#
# Iteration:  384
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.1165 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5821 - acc: 0.9000
#
#
# Iteration:  385
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2564 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2003 - acc: 0.8000
# Evaluating on test data
#
#
# Test Accuracy 0.68
#
# Test MCC:  0.13
# ------------
#
#
#
#
# Iteration:  386
# Epoch 1/2
# 2/2 [==============================] - 0s 7ms/step - loss: 3.3970 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.5867 - acc: 0.7000
#
#
# Iteration:  387
# Epoch 1/2
# 2/2 [==============================] - 0s 7ms/step - loss: 3.4982 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.5390 - acc: 0.7000
#
#
# Iteration:  388
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9326 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.8323 - acc: 0.9000
#
#
# Iteration:  389
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.6500 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5810 - acc: 0.7000
#
#
# Iteration:  390
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.5263 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3904 - acc: 0.9000
# Evaluating on test data
#
#
# Test Accuracy 0.68
#
# Test MCC:  0.11
# ------------
#
#
#
#
# Iteration:  391
# Epoch 1/2
# 2/2 [==============================] - 0s 7ms/step - loss: 1.8328 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.8956 - acc: 0.9000
#
#
# Iteration:  392
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.8013 - acc: 1.0000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.7322 - acc: 0.7000
#
#
# Iteration:  393
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.7538 - acc: 1.0000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.3847 - acc: 0.8000
#
#
# Iteration:  394
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1005 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.0770 - acc: 0.6000
#
#
# Iteration:  395
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.7155 - acc: 0.5000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.6123 - acc: 0.5000
# Evaluating on test data
#
#
# Test Accuracy 0.68
#
# Test MCC:  0.14
# ------------
#
#
#
#
# Iteration:  396
# Epoch 1/2
# 2/2 [==============================] - 0s 7ms/step - loss: 1.9301 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.0010 - acc: 0.5000
#
#
# Iteration:  397
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.5970 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.7988 - acc: 0.8000
#
#
# Iteration:  398
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7433 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4417 - acc: 0.8000
#
#
# Iteration:  399
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0198 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1939 - acc: 0.9000
#
#
# Iteration:  400
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.5981 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.6036 - acc: 0.8000
# Evaluating on training data
# Train Accuracy 0.77
#
# Train MCC:  0.39
# Evaluating on test data
#
#
# Test Accuracy 0.68
#
# Test MCC:  0.12
# ------------
#
#
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/Google Colab Data/StallCatcher/micro/MODEL_FOLDER/MODEL_V1_E0_400/assets
#
#
# Iteration:  401
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.3078 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.2744 - acc: 0.7000
#
#
# Iteration:  402
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.3933 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.2512 - acc: 0.9000
#
#
# Iteration:  403
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4702 - acc: 0.5000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.1223 - acc: 0.7000
#
#
# Iteration:  404
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.6660 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.5155 - acc: 0.5000
#
#
# Iteration:  405
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.3307 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.1062 - acc: 0.7000
# Evaluating on test data
#
#
# Test Accuracy 0.68
#
# Test MCC:  0.12
# ------------
#
#
#
#
# Iteration:  406
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 2.7443 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.8565 - acc: 0.9000
#
#
# Iteration:  407
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.1809 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.3708 - acc: 0.7000
#
#
# Iteration:  408
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.0705 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.6309 - acc: 0.8000
#
#
# Iteration:  409
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.3023 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.2337 - acc: 0.7000
#
#
# Iteration:  410
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.8816 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.7792 - acc: 0.6000
# Evaluating on test data
#
#
# Test Accuracy 0.69
#
# Test MCC:  0.12
# ------------
#
#
#
#
# Iteration:  411
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.2562 - acc: 0.6000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.8710 - acc: 0.7000
#
#
# Iteration:  412
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 3.2347 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4996 - acc: 0.7000
#
#
# Iteration:  413
# Epoch 1/2
# 2/2 [==============================] - 0s 6ms/step - loss: 3.7239 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7493 - acc: 0.7000
#
#
# Iteration:  414
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.0281 - acc: 0.9000
# Epoch 2/2
# 2/2 [==============================] - 0s 3ms/step - loss: 1.9039 - acc: 1.0000
#
#
# Iteration:  415
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 4.0823 - acc: 0.4000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.5350 - acc: 0.4000
# Evaluating on test data
#
#
# Test Accuracy 0.69
#
# Test MCC:  0.14
# ------------
#
#
#
#
# Iteration:  416
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.5862 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.7903 - acc: 0.8000
#
#
# Iteration:  417
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.3807 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 5ms/step - loss: 2.4552 - acc: 0.8000
#
#
# Iteration:  418
# Epoch 1/2
# 2/2 [==============================] - 0s 5ms/step - loss: 1.7783 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3133 - acc: 1.0000
#
#
# Iteration:  419
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4922 - acc: 0.8000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.2920 - acc: 0.8000
#
#
# Iteration:  420
# Epoch 1/2
# 2/2 [==============================] - 0s 4ms/step - loss: 3.3957 - acc: 0.7000
# Epoch 2/2
# 2/2 [==============================] - 0s 4ms/step - loss: 4.2301 - acc: 0.5000
# Evaluating on test data
#
#
# Test Accuracy 0.7
#
# Test MCC:  0.18
# ------------
#
#
#
#
# Iteration:  421
# Epoch 1/2
# 1/2 [==============>...............] - ETA: 0s - loss: 2.7996 - acc: 0.6000

# %% [markdown]
# PLOT VALIDATION MCC TIMELINE

# %%
plt.plot(test_mcc)

# %% [markdown]
# LOAD BEST MODEL

# %%
 model.load_model(MODEL_FILENAME + str(epoch))
